# %% [markdown]
# <a href="https://colab.research.google.com/github/AllergicAlligator/Test/blob/main/20220620.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #20220620
#
# [Python基礎講義](https://docs.google.com/presentation/d/140dHWSexhiarrdZVQ1Rf466LgfAlBQz2CPRtrToCe2Q/edit#slide=id.g10e2df5b7ef_0_0)

# %%
from PIL import Image

# %%
im = Image.open("download.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=317x159 at 0x7F05AB3EF950>

# %% [markdown]
# ## 讀取圖片的屬性

# %%
im.size
# Out:
# (317, 159)

# %%
im.format
# Out:
# 'JPEG'

# %%
im.mode
# Out:
# 'RGB'

# %% [markdown]
# ##調換色層

# %%
r, g, b = im.split()
im = Image.merge("RGB", (b, g, r))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7F05AA902FD0>

# %%
r, g, b = im.split()
im = Image.merge("RGB", (b, g, r))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7F05A2370C10>

# %% [markdown]
# ## 圖形縮放
#
# * resize

# %%
im.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F05A2392ED0>

# %%
im.resize((im.size[0]//3, im.size[1]//3))
# Out:
# <PIL.Image.Image image mode=RGB size=105x53 at 0x7F05A22DDE50>

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7F05A2370C10>

# %% [markdown]
# ##圖形旋轉(Image Rotation)
#
# *   Transpose
# *   Rotate

# %%
im.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7F05A233DCD0>

# %%
im.transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=159x317 at 0x7F05AA8E00D0>

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7F05A2370C10>
